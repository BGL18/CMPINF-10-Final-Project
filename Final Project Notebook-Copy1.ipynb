# %% [markdown]
# # Pitt Band Bikers Final Project
# ### Adam Funk, Brian Lindsay, Ryan O'Boyle

# %% [markdown]
# Welcome to the Pitt Band Bikers final Big Ideas project! The goal of our project was to analyze data to investigate what town was the best town to bike in throughout Alleghany County. Let's import our libraries and get into the data!

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25868/3878667929.py in <module>
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#       3 import numpy as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ## Air Quality in Pittsburgh
# #### Ryan O'Boyle

# %% [markdown]
# ### Introduction
# Air quality is a sneakily important category in considering the best town for biking in Pittsburgh. Air quality can have a drastic affect on the quality of ride a biker has. Especially factoring in the possibility of asthma, ensuring proper circulation throughout the body is extremely important. Biking in a place with the best possible air quality will help ensure the best performance and best time riding your bike

# %% [markdown]
# ### The Metric
# For my metric, I specifically averaged out the index value of the air quality on a day-to-day scale. Polling this information allows you to analyze the best city to bike throughout Pittsburgh. Through this, I was able to calculate a hierarchy for the best places in terms of bikers health throughout Pittsburgh

# %% [markdown]
# ### Importing our DataSet

# %%
air = pd.read_csv("daily-air-quality.csv", index_col="date", parse_dates=True)
air.head(10)
# Out:
#                          site parameter  index_value description  \
# date
# 2016-01-01      Lawrenceville     PM25B           25        Good
# 2016-01-01         Flag Plaza        CO            0        Good
# 2016-01-01  Harrison Township     OZONE           31        Good
# 2016-01-01             Avalon       SO2           10        Good
# 2016-01-01            Lincoln      PM25           35        Good
# 2016-01-01            Lincoln      PM10           11        Good
# 2016-01-01      South Fayette       SO2            3        Good
# 2016-01-01     North Braddock     PM10B           12        Good
# 2016-01-01       Parkway East        CO            4        Good
# 2016-01-01         Flag Plaza      PM10            7        Good
#
#            health_advisory health_effects
# date
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN
# 2016-01-01             NaN            NaN

# %% [markdown]
# ### Manipulating our Data
# Now, we want to look at this data specifically focusing on our index_value. To start with this, we will take a look at all average `index_value`'s for every town.

# %%
sorted = air.groupby("site")["index_value"].describe()
sorted.sort_values(by='mean', inplace=True)
sorted.head(50)
# Out:
#                         count       mean        std  min   25%   50%   75%  \
# site
# Lawrenceville 2        4528.0   3.116166   2.444475  0.0   2.0   3.0   4.0
# West Mifflin            301.0   6.335548   7.178930  0.0   1.0   4.0   9.0
# Clairton                329.0   7.273556  10.464717  0.0   1.0   3.0   9.0
# Flag Plaza             4002.0   9.949275  10.078134  0.0   0.0   8.0  16.0
# Glassport High Street  2272.0  17.089349  10.364575  2.0   9.0  15.0  22.0
# North Braddock         4882.0  18.011061  15.623459  0.0   4.0  16.0  28.0
# Liberty                2285.0  18.686652  19.607663  0.0   3.0  13.0  27.0
# South Fayette          4406.0  20.471403  20.725906  0.0   1.0   9.0  38.0
# Avalon                 3843.0  21.316419  21.709257  0.0   0.0  19.0  38.0
# Parkway East           6804.0  22.226337  16.880865  2.0   9.0  17.0  31.0
# Harrison Township      4367.0  24.319899  15.246246  0.0  11.5  23.0  35.0
# Pittsburgh              904.0  28.564159  16.449065  4.0  17.0  24.0  37.0
# Liberty 2              4468.0  32.238585  22.193320  0.0  15.0  27.0  45.0
# Lincoln                3574.0  35.108002  20.379058  2.0  19.0  30.0  49.0
# Lawrenceville          3805.0  38.125624  14.602190  0.0  28.0  37.0  47.0
#
#                          max
# site
# Lawrenceville 2         30.0
# West Mifflin            44.0
# Clairton                69.0
# Flag Plaza              57.0
# Glassport High Street   82.0
# North Braddock         114.0
# Liberty                137.0
# South Fayette          118.0
# Avalon                 115.0
# Parkway East           153.0
# Harrison Township      115.0
# Pittsburgh             129.0
# Liberty 2              163.0
# Lincoln                153.0
# Lawrenceville          129.0

# %% [markdown]
# ### Interpretations
# Lets look down on our initial towns to narrow down what we are looking for, by eliminating our top objects.
# * Lawrenceville 2 dictates that there are other parts of Lawrenceville with differing air quality, and we see on the bottom of this list that Lawrenceville with the worst air quality. This discrepancy removes Lawrenceville from contention
# * West Mifflin and Clairton have much too small of a data set, with their `count` field only adding up to 300
#
# This makes Flag Plaza the best town to bike based off of air quality!

# %% [markdown]
# ## Data Skewness

# %% [markdown]
# We want to further analyze this data to ensure skewness within our datasets, as we want to check the validity of our data. Lets look at the list of sensors that our data set runs

# %%
air_sensors = pd.read_csv("air-quality-sensors.csv", index_col="site_name", parse_dates=True)
enabled_mask = air_sensors['enabled'] == 't'
air_sensors[enabled_mask]
# Out:
#                                                               description  \
# site_name
# Harrison Township                 Harrison Township Ozone and NO/NOx Site
# South Fayette                                    South Fayette Ozone Site
# Lawrenceville                           Lawrenceville Ozone, and Met Site
# Liberty                  Liberty Borough South Allegheny High School Site
# Avalon                                                 Avalon PM-2.5 Site
# Lawrenceville 2                                            LV2 NCORE site
# North Braddock                                             PM-10 BAM Site
# Clairton                                             Clairton PM-2.5 Site
# Parkway East                                 Near Road CO and NO2 Monitor
# Liberty 2                Liberty Borough South Allegheny High School Site
# Glassport High Street                         Glassport High Street PM-10
# USS Clairton Sodar Site                                   Sodar Rass Site
#
#                         air_now_mnemonic  \
# site_name
# Harrison Township                    HT1
# South Fayette                        SF1
# Lawrenceville                        LV1
# Liberty                              NaN
# Avalon                               NaN
# Lawrenceville 2                      NaN
# North Braddock                       NaN
# Clairton                             NaN
# Parkway East                         NaN
# Liberty 2                            LB1
# Glassport High Street                NaN
# USS Clairton Sodar Site              NaN
#
#                                                                    address  \
# site_name
# Harrison Township        Highlands Senior High School - 1500 Pacific Av...
# South Fayette            South Fayette Elementary School - 3640 Old Oak...
# Lawrenceville            Allegheny County Health Department - 301 39th ...
# Liberty                  South Allegheny High School - 2743 Washington ...
# Avalon                             520 Orchard Street Pittsburgh, PA 15202
# Lawrenceville 2          Allegheny County Health Department - 01 39th S...
# North Braddock           North Braddock Borough Building - 600 Anderson...
# Clairton                 Clairton Educational Center - 501 Waddel Stree...
# Parkway East             Hosanna House Event Center - 400 Sherwood Road...
# Liberty 2                South Allegheny High School - 2743 Washington ...
# Glassport High Street       Water Tower on High Street Glassport, PA 15045
# USS Clairton Sodar Site                                                NaN
#
#                           latitude  longitude enabled
# site_name
# Harrison Township        40.613864 -79.729569       t
# South Fayette            40.375647 -80.169931       t
# Lawrenceville            40.465433 -79.960742       t
# Liberty                  40.323856 -79.868064       t
# Avalon                   40.499789 -80.071347       t
# Lawrenceville 2          40.465433 -79.960742       t
# North Braddock           40.402267 -79.860942       t
# Clairton                 40.294381 -79.885303       t
# Parkway East             40.437431 -79.863572       t
# Liberty 2                40.323856 -79.868064       t
# Glassport High Street    40.326019 -79.881747       t
# USS Clairton Sodar Site        NaN        NaN       t

# %% [markdown]
# So this is worrying. While we do have a subtantial amount of data from these locations, we only have 12 actively collecting sensors, collecting from a very minimal amount of locations. This is an extraordinarily small amount of data to collect from, making this dataset redundant in the analysis of all 3 of our datasets. While Flag Plaza is the best town to bike in based off of air quality in this data set, there is not enough data to make a true final conclusion.

# %% [markdown]
# ## Traffic Count Data Set

# %% [markdown]
# ##### Adam Funk

# %% [markdown]
# **Purpose:** The purpose of the Jupyter Notebook is to visualize data from the Traffic Count Data Set retrieved from WPRDC. I intend to identify any trends from this data set and use this to further our argument on which neighborhood is the best environment for biking in Pittsburgh. With this data set, it is important to consider that this is an amalgamation of various traffic studies - including intersection studies, speed hump studies, Biking PGH studies just to name a few. The concentration of efforts in certain neighborhoods may skew results; however, no concentration was noted by the data set.

# %% [markdown]
# ### Read in CSV File

# %% [markdown]
# Let's read in our csv file containing our data and use the head function to get an idea of how our data set is organized.

# %%
data = pd.read_csv("traffic_count.csv")

# %%
data.head()
# Out:
#            id  device_id    record_oid count_start_date count_end_date  \
# 0  1011743669         85  1.445865e+09       2019-04-18     2019-04-26
# 1  1026101993        140  1.121444e+09       2019-01-24            NaN
# 2  1032382575         11  1.539893e+09       2018-08-28     2018-09-04
# 3   103627606          9  7.341951e+08       2018-07-17     2018-08-01
# 4  1039546167        144           NaN              NaN            NaN
#
#    average_daily_car_traffic  average_daily_bike_traffic counter_number  \
# 0                     4949.0                         NaN              6
# 1                        NaN                         NaN            NaN
# 2                        NaN                         NaN            NaN
# 3                     2741.0                         NaN            NaN
# 4                        NaN                         NaN            NaN
#
#          counter_type  speed_limit  ...  longitude   latitude  \
# 0            StatTrak         25.0  ... -79.967772  40.455733
# 1  Intersection Study          NaN  ... -79.952249  40.466157
# 2                 NaN         35.0  ... -80.076469  40.460717
# 3            StatTrak         25.0  ... -79.914335  40.437379
# 4                 NaN          NaN  ... -80.019211  40.490794
#
#             neighborhood  council_district  ward        tract  \
# 0            Polish Hill               7.0   6.0  42003060500
# 1  Central Lawrenceville               7.0   9.0  42003090200
# 2                Windgap               2.0  28.0  42003563000
# 3    Squirrel Hill South               5.0  14.0  42003140800
# 4            Perry North               1.0  26.0  42003260200
#
#    public_works_division pli_division  police_zone  fire_zone
# 0                    6.0          6.0          2.0        2-6
# 1                    2.0          9.0          2.0        3-6
# 2                    5.0         28.0          6.0       1-16
# 3                    3.0         14.0          4.0       2-18
# 4                    1.0         26.0          1.0       1-15
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Average Daily Car Traffic

# %% [markdown]
# Let's filter a subset of the data to look at neighborhoods and average daily car traffic (dropping NaN values).

# %%
data_car_neighbor = data[["average_daily_car_traffic", "neighborhood"]].dropna()

# %% [markdown]
# In our data set, it appears that we have multiple occurrences of some neighborhoods. Let's use the groupby() function and lambda function to set these average car traffic counts by neighborhood.

# %%
group_data = data_car_neighbor.groupby("neighborhood").agg(lambda x: x.tolist())

# %% [markdown]
# Let's iterate through our data frame and total up the average car traffic measures for each neighborhood.

# %%
my_list = []
for index, row in group_data.iterrows():
    my_list.append(sum(row["average_daily_car_traffic"]))

# %% [markdown]
# Finally, let's create a new column with these total car traffic values in our data frame.

# %%
group_data.insert(1, "total_car_traffic", my_list)

# %%
display(group_data)
# Out:
#                  average_daily_car_traffic  total_car_traffic
# neighborhood
# Allegheny Center                  [2386.0]             2386.0
# Allegheny West                     [477.0]              477.0
# Arlington                 [2224.0, 2347.0]             4571.0
# Beechview          [2046.0, 763.0, 1446.0]             4255.0
# Beltzhoover                       [1577.0]             1577.0
# ...                                    ...                ...
# Summer Hill                        [937.0]              937.0
# Upper Hill          [1530.0, 927.0, 403.0]             2860.0
# West Oakland                      [2585.0]             2585.0
# Westwood                  [9600.0, 5800.0]            15400.0
# Windgap                    [2931.0, 131.0]             3062.0
#
# [64 rows x 2 columns]

# %% [markdown]
# We will now use a bar plot to visualize the total car traffic by neighborhood.

# %%
group_data.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='neighborhood'>

# %% [markdown]
# It's nice to have a visualization of the total car traffic throughout neighborhoods in Pittsburgh, but what if we could just pull the neighborhood with the least total car traffic?

# %%
print(group_data[group_data.total_car_traffic == group_data.total_car_traffic.min()])
# Out:
#                  average_daily_car_traffic  total_car_traffic
# neighborhood
# South Side Flats                   [115.0]              115.0

# %% [markdown]
# The code above says that South Side Flats has the least amount of total car traffic. That's helpful information but what if we could look at the top 5 neighborhoods with least total car traffic?

# %%
group_data.sort_values("total_car_traffic").head(5)
# Out:
#                          average_daily_car_traffic  total_car_traffic
# neighborhood
# South Side Flats                           [115.0]              115.0
# Lincoln Place                              [126.0]              126.0
# Lincoln-Lemington-Belmar                   [195.0]              195.0
# Fineview                                   [419.0]              419.0
# Allegheny West                             [477.0]              477.0

# %% [markdown]
# Above we have displayed the top 5 neighborhoods with the lowest total car traffic. While this is certainly useful information, what else can we learn from this dataset? Let's look at what columns our data set contains.

# %%
data.columns
# Out:
# Index(['id', 'device_id', 'record_oid', 'count_start_date', 'count_end_date',
#        'average_daily_car_traffic', 'average_daily_bike_traffic',
#        'counter_number', 'counter_type', 'speed_limit', 'max_speed',
#        'median_speed', 'percent_over_limit', 'speed85_percent',
#        'speed95_percent', 'longitude', 'latitude', 'neighborhood',
#        'council_district', 'ward', 'tract', 'public_works_division',
#        'pli_division', 'police_zone', 'fire_zone'],
#       dtype='object')

# %% [markdown]
# It looks like we have 2 additional columns that may be of use to us - average daily bike traffic and percent over the speed limit. The more daily bike traffic indicates others bike in that neighborhood frequently - indicating it is a safe environment. Additionally, the higher the percent of drivers over the speed limit increases the liklihood for car accidents which can endanger bikers. First, let's consider the average daily bike traffic.

# %% [markdown]
# ### Average Daily Bike Traffic

# %%
bike_neighbor_data = data[["average_daily_bike_traffic", "neighborhood"]].dropna()

# %% [markdown]
# Considering the daily bike traffic, let's group by neighborhood and see how much bike traffic data has been recorded.

# %%
bike_data = bike_neighbor_data.groupby("neighborhood").agg(lambda x: x.tolist())

# %%
display(bike_data)
# Out:
#                  average_daily_bike_traffic
# neighborhood
# Central Oakland                     [198.0]
# North Oakland                 [88.0, 102.0]
# South Oakland              [2063.0, 1278.0]
# South Side Flats             [954.0, 892.0]

# %% [markdown]
# Looking at the dataset above, it seems that there is very little data concerning bike traffic. However, we can still look at the data we have available regarding bike traffic and calculate total bike traffic.

# %%
bike_totals = []
for index, row in bike_data.iterrows():
    bike_totals.append(sum(row["average_daily_bike_traffic"]))

# %%
bike_data.insert(1, "total_bike_traffic", bike_totals)

# %%
display(bike_data)
# Out:
#                  average_daily_bike_traffic  total_bike_traffic
# neighborhood
# Central Oakland                     [198.0]               198.0
# North Oakland                 [88.0, 102.0]               190.0
# South Oakland              [2063.0, 1278.0]              3341.0
# South Side Flats             [954.0, 892.0]              1846.0

# %% [markdown]
# Let's use another bar chart to visualize the total bike traffic by neighborhood.

# %%
bike_data.plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='neighborhood'>

# %% [markdown]
# From the bar chart above, it is clear that South Oakland has the most bike traffic; however, South Side Flats - the neighborhood identified with the lowest total car traffic has a comparable amount of bike traffic.

# %%
bike_data.sort_values("total_bike_traffic", ascending = False)
# Out:
#                  average_daily_bike_traffic  total_bike_traffic
# neighborhood
# South Oakland              [2063.0, 1278.0]              3341.0
# South Side Flats             [954.0, 892.0]              1846.0
# Central Oakland                     [198.0]               198.0
# North Oakland                 [88.0, 102.0]               190.0

# %% [markdown]
# After sorting out data by total bike traffic, it becomes clear that **South Oakland** has the most bike traffic and **South Side Flats** has the second most bike traffic of the data collected.

# %% [markdown]
# ### Percent Over Speed Limit

# %% [markdown]
# Finally, let's consider the percent over speed limit parameter of this data set. This can indicate how safe the resulting neighborhood is for biking by indicating how many drivers exceed the local speed limits.

# %%
speed_limit_neighborhood_data = data[["percent_over_limit", "neighborhood"]].dropna()

# %%
speed_limit_neighborhood_data
# Out:
#      percent_over_limit           neighborhood
# 0                  77.0            Polish Hill
# 2                  28.0                Windgap
# 3                  70.0    Squirrel Hill South
# 5                   2.0      Central Northside
# 7                  58.0            Polish Hill
# ..                  ...                    ...
# 407                13.0         Homewood South
# 408                17.0         Homewood South
# 410                29.0             Bloomfield
# 411                10.0             Bloomfield
# 412                31.0  Central Lawrenceville
#
# [240 rows x 2 columns]

# %% [markdown]
# Again, let's group together repeating neighborhoods using the `groupby` function.

# %%
speed_limit_data = speed_limit_neighborhood_data.groupby("neighborhood").agg(lambda x: x.tolist())

# %%
speed_limit_data
# Out:
#                                                  percent_over_limit
# neighborhood
# Allegheny Center                                             [65.0]
# Allegheny West                                               [11.0]
# Arlington                                              [73.0, 50.0]
# Beechview                                        [85.0, 20.0, 72.0]
# Bloomfield        [17.0, 14.0, 14.0, 91.0, 15.0, 8.0, 23.0, 29.0...
# ...                                                             ...
# Summer Hill                                                  [55.0]
# Upper Hill                                        [15.0, 0.0, 58.0]
# West Oakland                                                 [28.0]
# Westwood                                               [32.0, 87.0]
# Windgap                                          [28.0, 44.0, 29.0]
#
# [62 rows x 1 columns]

# %% [markdown]
# Now that we have grouped repeated neighborhoods into a list, lets find the average percent over the speed limit for each neighborhood. We can use the mean function from the numpy package we imported above.

# %%
speed_totals = []
for index, row in speed_limit_data.iterrows():
    speed_totals.append(np.mean(row["percent_over_limit"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25868/1491280573.py in <module>
#       1 speed_totals = []
#       2 for index, row in speed_limit_data.iterrows():
# ----> 3     speed_totals.append(np.mean(row["percent_over_limit"]))
#
# NameError: name 'np' is not defined

# %%
speed_limit_data.insert(1, "average_percent_over_limit", speed_totals)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25868/2864222930.py in <module>
# ----> 1 speed_limit_data.insert(1, "average_percent_over_limit", speed_totals)
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    4416             raise TypeError("loc must be int")
#    4417
# -> 4418         value = self._sanitize_column(value)
#    4419         self._mgr.insert(loc, column, value)
#    4420
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (0) does not match length of index (62)

# %%
display(speed_limit_data)
# Out:
#                                                  percent_over_limit
# neighborhood
# Allegheny Center                                             [65.0]
# Allegheny West                                               [11.0]
# Arlington                                              [73.0, 50.0]
# Beechview                                        [85.0, 20.0, 72.0]
# Bloomfield        [17.0, 14.0, 14.0, 91.0, 15.0, 8.0, 23.0, 29.0...
# ...                                                             ...
# Summer Hill                                                  [55.0]
# Upper Hill                                        [15.0, 0.0, 58.0]
# West Oakland                                                 [28.0]
# Westwood                                               [32.0, 87.0]
# Windgap                                          [28.0, 44.0, 29.0]
#
# [62 rows x 1 columns]

# %% [markdown]
# Let's make use of the bar graph plot to visualize what this average percent of people driving over the speed limit looks like.

# %%
speed_limit_data.plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25868/4258795473.py in <module>
# ----> 1 speed_limit_data.plot(kind = "bar")
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# Now, let's sort these values from low to high to identify the neighborhoods with the lowest percent of drivers exceeding the speed limit.

# %%
speed_limit_data.sort_values("average_percent_over_limit")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25868/2114779283.py in <module>
# ----> 1 speed_limit_data.sort_values("average_percent_over_limit")
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\envs\environment\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'average_percent_over_limit'

# %% [markdown]
# After sorting these values, we see - for a third time - **South Side Flats** is a relevant neighborhood as this has the lowest percent of drivers exceeding the speed limits. However, **Lincoln Place** and **Allegheny West** are also relevant neighborhoods as well.

# %% [markdown]
# # Bike-Related Crashes
# ## Brian Lindsay
# #### Introduction
# Bikes must share roads with other vehicle operators. Unfortunately, incidents occur. The object of this notebook section is to determine which neighborhood in Pittsburgh is the best for bike safety in terms of the least amount of bike incidents.

# %% [markdown]
# First, we'll import pandas as necessary.

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Following that, we will import our dataset, which is 2020 crash data in Allegheny County, and sort it by the crash identitfication number

# %%
crashData = pd.read_csv("Allegheny County Crash Data 2020.csv", sep = ",")

# %%
crashData.sort_values("CRASH_CRN")
# Out:
#        CRASH_CRN  DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  \
# 0     2020000005        11             2          2301       02301
# 1     2020000014        11             2          2301       02301
# 2     2020000016        11             2          2301       02301
# 3     2020000020        11             2          2113       02113
# 4     2020000023        11             2          2301       02503
# ...          ...       ...           ...           ...         ...
# 9858  2021017633        11             2          2116       02116
# 9859  2021018779        11             2          2464       00000
# 9860  2021019758        11             2          2301       02301
# 9861  2021021042        11             2          2301       02301
# 9862  2021021504        11             2          2301       68B03
#
#       CRASH_YEAR  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  HOUR_OF_DAY  ...  \
# 0           2020            1            4         55.0          0.0  ...
# 1           2020            1            4        140.0          1.0  ...
# 2           2020            1            4         53.0          0.0  ...
# 3           2020            1            4        315.0          3.0  ...
# 4           2020            1            4        152.0          1.0  ...
# ...          ...          ...          ...          ...          ...  ...
# 9858        2020           10            7       1845.0         18.0  ...
# 9859        2020           12            6        630.0          6.0  ...
# 9860        2020           12            4       1245.0         12.0  ...
# 9861        2020           11            3       1830.0         18.0  ...
# 9862        2020           12            2        614.0          6.0  ...
#
#       LANE_COUNT  RDWY_ORIENT  ROAD_OWNER  ROUTE  SPEED_LIMIT  SEGMENT  \
# 0            2.0            S           4    NaN         25.0      NaN
# 1            2.0            N           4    NaN         25.0      NaN
# 2            2.0            S           2   0019         35.0    251.0
# 3            2.0            N           4    NaN         25.0      NaN
# 4            4.0            S           4    NaN         25.0      NaN
# ...          ...          ...         ...    ...          ...      ...
# 9858         2.0            S           2   4003         45.0     17.0
# 9859         2.0            N           2   0028         65.0    374.0
# 9860         2.0            S           4    NaN         25.0      NaN
# 9861         2.0            N           4    NaN         25.0      NaN
# 9862         2.0            E           1   0376         55.0    760.0
#
#       OFFSET          STREET_NAME  TOT_INJ_COUNT  SCHOOL_BUS_UNIT
# 0        NaN          COMSTOCK WY              0              NaN
# 1        NaN           STANTON AV              0              NaN
# 2      291.0      SAW MILL RUN BL              2              NaN
# 3        NaN            DATURA DR              0              NaN
# 4        NaN      COMMONWEALTH PL              0              NaN
# ...      ...                  ...            ...              ...
# 9858  2022.0          MCKNIGHT RD              1              NaN
# 9859  3802.0  ALLEGHENY VALLEY EX              0              NaN
# 9860     NaN            SENECA ST              1              NaN
# 9861     NaN              FORD ST              0              NaN
# 9862  2477.0      PENN LINCOLN PY              1              NaN
#
# [9863 rows x 190 columns]

# %% [markdown]
# This is a lot of rows, mostly due to the fact that this is data for the whole county, not just Pittsburgh. To circumvent this, we apply a mask to the dataset to only show data within Pittsburgh using the Municipality Code 2301

# %%
pghQuery = crashData["MUNICIPALITY"] == 2301
pghCrashes = crashData[pghQuery]
pghCrashes
# Out:
#        CRASH_CRN  DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  \
# 0     2020000005        11             2          2301       02301
# 1     2020000014        11             2          2301       02301
# 2     2020000016        11             2          2301       02301
# 4     2020000023        11             2          2301       02503
# 12    2020000188        11             2          2301       02301
# ...          ...       ...           ...           ...         ...
# 9855  2021016340        11             2          2301       00000
# 9857  2021016383        11             2          2301       00000
# 9860  2021019758        11             2          2301       02301
# 9861  2021021042        11             2          2301       02301
# 9862  2021021504        11             2          2301       68B03
#
#       CRASH_YEAR  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  HOUR_OF_DAY  ...  \
# 0           2020            1            4         55.0          0.0  ...
# 1           2020            1            4        140.0          1.0  ...
# 2           2020            1            4         53.0          0.0  ...
# 4           2020            1            4        152.0          1.0  ...
# 12          2020            1            4       1621.0         16.0  ...
# ...          ...          ...          ...          ...          ...  ...
# 9855        2020           11            3       2345.0         23.0  ...
# 9857        2020           11            2       1730.0         17.0  ...
# 9860        2020           12            4       1245.0         12.0  ...
# 9861        2020           11            3       1830.0         18.0  ...
# 9862        2020           12            2        614.0          6.0  ...
#
#       LANE_COUNT  RDWY_ORIENT  ROAD_OWNER  ROUTE  SPEED_LIMIT  SEGMENT  \
# 0            2.0            S           4    NaN         25.0      NaN
# 1            2.0            N           4    NaN         25.0      NaN
# 2            2.0            S           2   0019         35.0    251.0
# 4            4.0            S           4    NaN         25.0      NaN
# 12           2.0            E           4    NaN          NaN      NaN
# ...          ...          ...         ...    ...          ...      ...
# 9855         2.0            E           1   0376         55.0    684.0
# 9857         3.0            E           1   0376         55.0    740.0
# 9860         2.0            S           4    NaN         25.0      NaN
# 9861         2.0            N           4    NaN         25.0      NaN
# 9862         2.0            E           1   0376         55.0    760.0
#
#       OFFSET      STREET_NAME  TOT_INJ_COUNT  SCHOOL_BUS_UNIT
# 0        NaN      COMSTOCK WY              0              NaN
# 1        NaN       STANTON AV              0              NaN
# 2      291.0  SAW MILL RUN BL              2              NaN
# 4        NaN  COMMONWEALTH PL              0              NaN
# 12       NaN           EVA ST              1              NaN
# ...      ...              ...            ...              ...
# 9855  2615.0  PENN LINCOLN PY              1              NaN
# 9857  1320.0  PENN LINCOLN PY              1              NaN
# 9860     NaN        SENECA ST              1              NaN
# 9861     NaN          FORD ST              0              NaN
# 9862  2477.0  PENN LINCOLN PY              1              NaN
#
# [3533 rows x 190 columns]

# %% [markdown]
# We then apply another mask to this dataset to display only bicycle-related incidents in Pittsburgh

# %%
bikeQuery = pghCrashes["BICYCLE"] > 0
pghBikeCrashes = pghCrashes[bikeQuery]
pghBikeCrashes
# Out:
#        CRASH_CRN  DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  \
# 118   2020001985        11             2          2301       02301
# 191   2020003297        11             2          2301       02301
# 286   2020004543        11             2          2301       02301
# 305   2020004782        11             2          2301       02301
# 906   2020012534        11             2          2301       02301
# 1259  2020016587        11             2          2301       02301
# 1500  2020019328        11             2          2301       02301
# 1920  2020023876        11             2          2301       02301
# 2053  2020025253        11             2          2301       02301
# 2497  2020030596        11             2          2301       02301
# 3243  2020040360        11             2          2301       02301
# 3395  2020041846        11             2          2301       02301
# 3994  2020048944        11             2          2301       02301
# 4028  2020049462        11             2          2301       02301
# 4475  2020054491        11             2          2301       02301
# 4514  2020055062        11             2          2301       02301
# 4991  2020060867        11             2          2301       02301
# 5805  2020070126        11             2          2301       02301
# 5917  2020071336        11             2          2301       02301
# 5969  2020071961        11             2          2301       02301
# 6034  2020072654        11             2          2301       02301
# 6904  2020082310        11             2          2301       02301
# 7595  2020090493        11             2          2301       02301
# 7904  2020093891        11             2          2301       02301
# 7936  2020094287        11             2          2301       02301
# 8125  2020096272        11             2          2301       02301
#
#       CRASH_YEAR  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  HOUR_OF_DAY  ...  \
# 118         2020            1            3        654.0          6.0  ...
# 191         2020            1            5       1938.0         19.0  ...
# 286         2020            1            5       1400.0         14.0  ...
# 305         2020            1            2       1355.0         13.0  ...
# 906         2020            2            1       1649.0         16.0  ...
# 1259        2020            2            4       1850.0         18.0  ...
# 1500        2020            2            5       2208.0         22.0  ...
# 1920        2020            3            6        840.0          8.0  ...
# 2053        2020            2            4       2014.0         20.0  ...
# 2497        2020            4            4       1532.0         15.0  ...
# 3243        2020            5            5       1639.0         16.0  ...
# 3395        2020            5            4       1220.0         12.0  ...
# 3994        2020            6            3        414.0          4.0  ...
# 4028        2020            6            4       1800.0         18.0  ...
# 4475        2020            7            7       1530.0         15.0  ...
# 4514        2020            7            2       1826.0         18.0  ...
# 4991        2020            7            6       1642.0         16.0  ...
# 5805        2020            8            4        850.0          8.0  ...
# 5917        2020            9            3       2230.0         22.0  ...
# 5969        2020            9            5       1610.0         16.0  ...
# 6034        2020            9            1       1244.0         12.0  ...
# 6904        2020           10            2       1400.0         14.0  ...
# 7595        2020           10            4        848.0          8.0  ...
# 7904        2020           10            5       1900.0         19.0  ...
# 7936        2020           11            6       1400.0         14.0  ...
# 8125        2020           11            4       1843.0         18.0  ...
#
#       LANE_COUNT  RDWY_ORIENT  ROAD_OWNER  ROUTE  SPEED_LIMIT  SEGMENT  \
# 118          3.0            S           4    NaN         25.0      NaN
# 191          3.0            S           4    NaN         35.0      NaN
# 286          1.0            S           4    NaN         25.0      NaN
# 305          2.0            S           4    NaN         25.0      NaN
# 906          2.0            S           4    NaN         25.0      NaN
# 1259         2.0            S           4    NaN         25.0      NaN
# 1500         3.0            S           4    NaN         25.0      NaN
# 1920         2.0            N           4    NaN         25.0      NaN
# 2053         2.0            S           4    NaN         25.0      NaN
# 2497         2.0            N           4    NaN         25.0      NaN
# 3243         2.0            N           4    NaN         25.0      NaN
# 3395         2.0            S           4    NaN         25.0      NaN
# 3994         3.0            E           4    NaN         25.0      NaN
# 4028         2.0            N           4    NaN         25.0      NaN
# 4475         2.0            W           4    NaN         25.0      NaN
# 4514         2.0            E           4    NaN         35.0      NaN
# 4991         2.0            N           4    NaN         35.0      NaN
# 5805         1.0            E           4    NaN         25.0      NaN
# 5917         2.0            W           4    NaN         25.0      NaN
# 5969         2.0            W           4    NaN         25.0      NaN
# 6034         2.0            E           4    NaN         25.0      NaN
# 6904         2.0            N           4    NaN         25.0      NaN
# 7595         2.0            N           4    NaN         25.0      NaN
# 7904         2.0            E           4    NaN         25.0      NaN
# 7936         2.0            E           4    NaN         25.0      NaN
# 8125         2.0            N           4    NaN         25.0      NaN
#
#       OFFSET          STREET_NAME  TOT_INJ_COUNT  SCHOOL_BUS_UNIT
# 118      NaN         ALLEGHENY AV              1              NaN
# 191      NaN          ATLANTIC AV              1              NaN
# 286      NaN             GROSS ST              1              NaN
# 305      NaN        BELLEFIELD AV              1              NaN
# 906      NaN              SHAW AV              1              NaN
# 1259     NaN            EDMOND ST              1              NaN
# 1500     NaN             SHADY AV              1              NaN
# 1920     NaN      S BELLEFIELD AV              1              NaN
# 2053     NaN          S NEGLEY AV              1              NaN
# 2497     NaN            CENTRE AV              1              NaN
# 3243     NaN              32ND ST              1              NaN
# 3395     NaN           BINGHAM ST              1              NaN
# 3994     NaN  BRIGHTON HEIGHTS BL              1              NaN
# 4028     NaN            SINGER PL              1              NaN
# 4475     NaN          SHERWOOD AV              1              NaN
# 4514     NaN         BEECHWOOD BL              1              NaN
# 4991     NaN          E CARSON ST              1              NaN
# 5805     NaN          PEMBROKE PL              1              NaN
# 5917     NaN         ELLSWORTH AV              1              NaN
# 5969     NaN             MCKEE PL              1              NaN
# 6034     NaN           LIBERTY AV              1              NaN
# 6904     NaN          ROBINSON ST              1              NaN
# 7595     NaN        DEVONSHIRE ST              1              NaN
# 7904     NaN           STANTON AV              1              NaN
# 7936     NaN              PENN AV              1              NaN
# 8125     NaN            MURRAY AV              1              NaN
#
# [26 rows x 190 columns]

# %% [markdown]
# Thankfully, only 26 rows! However, there are still almost 200 columns to consider. To alleviate this, we take a subset of the dataset to see only columns that may help us determine the neighborhood with the least amount of crashes.

# %%
pghBikeCrashes2 = pghBikeCrashes[["CRASH_CRN","CRASH_MONTH","DAY_OF_WEEK","TIME_OF_DAY","LOCATION_TYPE","BICYCLE_COUNT","FATAL_COUNT","INJURY_COUNT","BICYCLE_DEATH_COUNT","BICYCLE_MAJ_INJ_COUNT","DEC_LAT","DEC_LONG","RDWY_SEQ_NUM","ADJ_RDWY_SEQ","ROAD_OWNER","STREET_NAME"]]
pghBikeCrashes2
# Out:
#        CRASH_CRN  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  LOCATION_TYPE  \
# 118   2020001985            1            3        654.0              0
# 191   2020003297            1            5       1938.0              0
# 286   2020004543            1            5       1400.0              0
# 305   2020004782            1            2       1355.0              0
# 906   2020012534            2            1       1649.0              0
# 1259  2020016587            2            4       1850.0              0
# 1500  2020019328            2            5       2208.0              0
# 1920  2020023876            3            6        840.0              0
# 2053  2020025253            2            4       2014.0              0
# 2497  2020030596            4            4       1532.0              0
# 3243  2020040360            5            5       1639.0              0
# 3395  2020041846            5            4       1220.0              0
# 3994  2020048944            6            3        414.0              0
# 4028  2020049462            6            4       1800.0              0
# 4475  2020054491            7            7       1530.0              0
# 4514  2020055062            7            2       1826.0              0
# 4991  2020060867            7            6       1642.0              7
# 5805  2020070126            8            4        850.0              0
# 5917  2020071336            9            3       2230.0              0
# 5969  2020071961            9            5       1610.0              0
# 6034  2020072654            9            1       1244.0              0
# 6904  2020082310           10            2       1400.0              0
# 7595  2020090493           10            4        848.0              0
# 7904  2020093891           10            5       1900.0              0
# 7936  2020094287           11            6       1400.0              0
# 8125  2020096272           11            4       1843.0              0
#
#       BICYCLE_COUNT  FATAL_COUNT  INJURY_COUNT  BICYCLE_DEATH_COUNT  \
# 118               1            0             1                    0
# 191               1            0             1                    0
# 286               1            0             1                    0
# 305               1            0             1                    0
# 906               1            0             1                    0
# 1259              1            0             1                    0
# 1500              1            0             1                    0
# 1920              1            0             1                    0
# 2053              1            0             1                    0
# 2497              1            0             1                    0
# 3243              1            0             1                    0
# 3395              1            0             1                    0
# 3994              1            0             1                    0
# 4028              1            0             1                    0
# 4475              1            0             1                    0
# 4514              1            0             1                    0
# 4991              1            0             1                    0
# 5805              1            0             1                    0
# 5917              1            0             1                    0
# 5969              1            0             1                    0
# 6034              1            0             1                    0
# 6904              1            0             1                    0
# 7595              1            0             1                    0
# 7904              1            0             1                    0
# 7936              1            0             1                    0
# 8125              1            0             1                    0
#
#       BICYCLE_MAJ_INJ_COUNT  DEC_LAT  DEC_LONG  RDWY_SEQ_NUM  ADJ_RDWY_SEQ  \
# 118                       0  40.4515  -80.0189             5             5
# 191                       1  40.4566  -79.9397             6             6
# 286                       0  40.4647  -79.9442             3             4
# 305                       0  40.4481  -79.9526             3             3
# 906                       0  40.4357  -79.9098             3             4
# 1259                      0  40.4612  -79.9481             3             4
# 1500                      0  40.4380  -79.9194             3             4
# 1920                      0  40.4439  -79.9508             6             6
# 2053                      1  40.4583  -79.9338             5             5
# 2497                      0  40.4487  -79.9616             4             3
# 3243                      0  40.4602  -79.9693             3             4
# 3395                      0  40.4294  -79.9947             4             3
# 3994                      0  40.4789  -80.0430             6             6
# 4028                      0  40.4517  -79.8835             3             3
# 4475                      1  40.4554  -80.0537             4             3
# 4514                      0  40.4376  -79.9135             3             3
# 4991                      0  40.4310  -80.0017             6             6
# 5805                      0  40.4511  -79.9358             3             4
# 5917                      0  40.4509  -79.9431             3             4
# 5969                      0  40.4366  -79.9555             3             4
# 6034                      0  40.4601  -79.9460             4             3
# 6904                      0  40.4403  -79.9656             4             3
# 7595                      0  40.4514  -79.9454             4             3
# 7904                      0  40.4687  -79.9159             3             3
# 7936                      0  40.4662  -79.9520             3             3
# 8125                      0  40.4298  -79.9235             4             3
#
#       ROAD_OWNER          STREET_NAME
# 118            4         ALLEGHENY AV
# 191            4          ATLANTIC AV
# 286            4             GROSS ST
# 305            4        BELLEFIELD AV
# 906            4              SHAW AV
# 1259           4            EDMOND ST
# 1500           4             SHADY AV
# 1920           4      S BELLEFIELD AV
# 2053           4          S NEGLEY AV
# 2497           4            CENTRE AV
# 3243           4              32ND ST
# 3395           4           BINGHAM ST
# 3994           4  BRIGHTON HEIGHTS BL
# 4028           4            SINGER PL
# 4475           4          SHERWOOD AV
# 4514           4         BEECHWOOD BL
# 4991           4          E CARSON ST
# 5805           4          PEMBROKE PL
# 5917           4         ELLSWORTH AV
# 5969           4             MCKEE PL
# 6034           4           LIBERTY AV
# 6904           4          ROBINSON ST
# 7595           4        DEVONSHIRE ST
# 7904           4           STANTON AV
# 7936           4              PENN AV
# 8125           4            MURRAY AV

# %% [markdown]
# We can sort the dataset by the number of major injuries to see the least severe bike incidents

# %%
pghBikeCrashes2.sort_values("BICYCLE_MAJ_INJ_COUNT")
# Out:
#        CRASH_CRN  CRASH_MONTH  DAY_OF_WEEK  TIME_OF_DAY  LOCATION_TYPE  \
# 118   2020001985            1            3        654.0              0
# 7904  2020093891           10            5       1900.0              0
# 7595  2020090493           10            4        848.0              0
# 6904  2020082310           10            2       1400.0              0
# 6034  2020072654            9            1       1244.0              0
# 5969  2020071961            9            5       1610.0              0
# 5917  2020071336            9            3       2230.0              0
# 5805  2020070126            8            4        850.0              0
# 4991  2020060867            7            6       1642.0              7
# 4514  2020055062            7            2       1826.0              0
# 4028  2020049462            6            4       1800.0              0
# 7936  2020094287           11            6       1400.0              0
# 3994  2020048944            6            3        414.0              0
# 3243  2020040360            5            5       1639.0              0
# 2497  2020030596            4            4       1532.0              0
# 1920  2020023876            3            6        840.0              0
# 1500  2020019328            2            5       2208.0              0
# 1259  2020016587            2            4       1850.0              0
# 906   2020012534            2            1       1649.0              0
# 305   2020004782            1            2       1355.0              0
# 286   2020004543            1            5       1400.0              0
# 3395  2020041846            5            4       1220.0              0
# 8125  2020096272           11            4       1843.0              0
# 4475  2020054491            7            7       1530.0              0
# 2053  2020025253            2            4       2014.0              0
# 191   2020003297            1            5       1938.0              0
#
#       BICYCLE_COUNT  FATAL_COUNT  INJURY_COUNT  BICYCLE_DEATH_COUNT  \
# 118               1            0             1                    0
# 7904              1            0             1                    0
# 7595              1            0             1                    0
# 6904              1            0             1                    0
# 6034              1            0             1                    0
# 5969              1            0             1                    0
# 5917              1            0             1                    0
# 5805              1            0             1                    0
# 4991              1            0             1                    0
# 4514              1            0             1                    0
# 4028              1            0             1                    0
# 7936              1            0             1                    0
# 3994              1            0             1                    0
# 3243              1            0             1                    0
# 2497              1            0             1                    0
# 1920              1            0             1                    0
# 1500              1            0             1                    0
# 1259              1            0             1                    0
# 906               1            0             1                    0
# 305               1            0             1                    0
# 286               1            0             1                    0
# 3395              1            0             1                    0
# 8125              1            0             1                    0
# 4475              1            0             1                    0
# 2053              1            0             1                    0
# 191               1            0             1                    0
#
#       BICYCLE_MAJ_INJ_COUNT  DEC_LAT  DEC_LONG  RDWY_SEQ_NUM  ADJ_RDWY_SEQ  \
# 118                       0  40.4515  -80.0189             5             5
# 7904                      0  40.4687  -79.9159             3             3
# 7595                      0  40.4514  -79.9454             4             3
# 6904                      0  40.4403  -79.9656             4             3
# 6034                      0  40.4601  -79.9460             4             3
# 5969                      0  40.4366  -79.9555             3             4
# 5917                      0  40.4509  -79.9431             3             4
# 5805                      0  40.4511  -79.9358             3             4
# 4991                      0  40.4310  -80.0017             6             6
# 4514                      0  40.4376  -79.9135             3             3
# 4028                      0  40.4517  -79.8835             3             3
# 7936                      0  40.4662  -79.9520             3             3
# 3994                      0  40.4789  -80.0430             6             6
# 3243                      0  40.4602  -79.9693             3             4
# 2497                      0  40.4487  -79.9616             4             3
# 1920                      0  40.4439  -79.9508             6             6
# 1500                      0  40.4380  -79.9194             3             4
# 1259                      0  40.4612  -79.9481             3             4
# 906                       0  40.4357  -79.9098             3             4
# 305                       0  40.4481  -79.9526             3             3
# 286                       0  40.4647  -79.9442             3             4
# 3395                      0  40.4294  -79.9947             4             3
# 8125                      0  40.4298  -79.9235             4             3
# 4475                      1  40.4554  -80.0537             4             3
# 2053                      1  40.4583  -79.9338             5             5
# 191                       1  40.4566  -79.9397             6             6
#
#       ROAD_OWNER          STREET_NAME
# 118            4         ALLEGHENY AV
# 7904           4           STANTON AV
# 7595           4        DEVONSHIRE ST
# 6904           4          ROBINSON ST
# 6034           4           LIBERTY AV
# 5969           4             MCKEE PL
# 5917           4         ELLSWORTH AV
# 5805           4          PEMBROKE PL
# 4991           4          E CARSON ST
# 4514           4         BEECHWOOD BL
# 4028           4            SINGER PL
# 7936           4              PENN AV
# 3994           4  BRIGHTON HEIGHTS BL
# 3243           4              32ND ST
# 2497           4            CENTRE AV
# 1920           4      S BELLEFIELD AV
# 1500           4             SHADY AV
# 1259           4            EDMOND ST
# 906            4              SHAW AV
# 305            4        BELLEFIELD AV
# 286            4             GROSS ST
# 3395           4           BINGHAM ST
# 8125           4            MURRAY AV
# 4475           4          SHERWOOD AV
# 2053           4          S NEGLEY AV
# 191            4          ATLANTIC AV

# %% [markdown]
# Unfortunately, there is no automatic way to sort this data by neighborhood, as the dataset, even in its most narrowed-down form, is county data. Thankfully, the decimal latitude and longitudes of each incident are recorded. After manually finding the neighborhoods where each incident occurred based on latitude and longitude coordinates, the results are:
# * Allegheny West - 1 incident
# * South Side Flats - 1 incident
# * Highland Park - 1 incident
# * South Shore - 1 incident
# * East Hills - 1 incident
# * Brighton Heights - 1 incident
# * Strip District - 1 incident
# * Terrace Village - 1 incident
# * Sheraden - 1 incident, major
# * Friendship - 1 incident, major
# * Shadyside - 3 incidents
# * Bloomfield 4 incidents, 1 major incident
# * Squirrel Hill South - 3 incidents, North - 1 incident
# * Oakland North - 2 incidents, Central - 1 incident, West - 1 incident

# %% [markdown]
# This can be easily tabulated, with non-major incidents getting a value of 1 and major incidents getting a value of 1.5

# %%
neighborhoodIncidentData = pd.DataFrame({"Neighborhood" : ["Allegheny West","South Side Flats","Highland Park","South Shore","East Hills","Brighton Heights","Strip District","Terrace Village","Sheraden","Friendship","Shadyside","Bloomfield","Squirrel Hill South","Squirrel Hill North","North Oakland","Central Oakland","West Oakland"], "Incident Count" : [1,1,1,1,1,1,1,1,1.5,1.5,3,5.5,3,1.5,2,1,1]})
#neighborhoodIncidentData.sort_values("Incident Count")
neighborhoodIncidentData
# Out:
#            Neighborhood  Incident Count
# 0        Allegheny West             1.0
# 1      South Side Flats             1.0
# 2         Highland Park             1.0
# 3           South Shore             1.0
# 4            East Hills             1.0
# 5      Brighton Heights             1.0
# 6        Strip District             1.0
# 7       Terrace Village             1.0
# 8              Sheraden             1.5
# 9            Friendship             1.5
# 10            Shadyside             3.0
# 11           Bloomfield             5.5
# 12  Squirrel Hill South             3.0
# 13  Squirrel Hill North             1.5
# 14        North Oakland             2.0
# 15      Central Oakland             1.0
# 16         West Oakland             1.0

# %% [markdown]
# The last step in interpreting this data is to visualize it, which can be done using a choropleth map.

# %%
import geopandas
neighborhoods = geopandas.read_file("Neighborhoods/Neighborhoods_.shp")

# %%
incidentMap = neighborhoods.merge(neighborhoodIncidentData, how='left', left_on='hood', right_on='Neighborhood')

# %%
incidentMap.plot(column='Incident Count', # set the data to be used for coloring
               cmap='OrRd',              # choose a color palette
               edgecolor="white",        # outline the districts in white
               legend=True,              # show the legend
               legend_kwds={'label': "Number of Incidents"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here is the final visualization. The neighborhoods with the least amount of bike incidents are the ones shaded the lightest. The worst neighborhoods by this metric are the darker-shaded ones. Additionally, the gray neighborhoods are the ones with no data to compare with.
#
# It can be seen from this choropleth map that the neighborhoods with the least amount of bike incidents are Brighton Heights, Allegheny West, Strip District, South Side Flats, South Shore, Highland Park, East Hills, Terrace Village, and West and Central Oakland.
